# %%
import cv2
import numpy as np
import requests

URL = 'http://192.168.1.66'

# %%
import traitlets
import ipywidgets.widgets as widgets
from IPython.display import display
from jetcam.utils import bgr8_to_jpeg
#from enesUtils import arr_to_img
from PIL import Image
from time import sleep

while True:
    cap = cv2.VideoCapture(URL + ":81/stream")
    if cap.isOpened():
        print("open")
        ret, frame = cap.read()
        if ret:
            gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
            gray = cv2.equalizeHist(gray)

    else:
        print("not open")

    #image = widgets.Image(format='jpeg', width=224, height=224)  # this width and height doesn't necessarily have to match the camera

    #camera_link = traitlets.dlink(frame, (image, 'value'), transform=bgr8_to_jpeg)

    display(Image.fromarray(frame, mode="RGB"))
    
    cap.release()
    cv2.destroyAllWindows()
    
    sleep(2)
# Out:
# open
# <PIL.Image.Image image mode=RGB size=640x480 at 0x7F7D9FF978>
# open
# <PIL.Image.Image image mode=RGB size=640x480 at 0x7F7D9FF898>
# open
# <PIL.Image.Image image mode=RGB size=640x480 at 0x7F7D9FF978>
# open
# <PIL.Image.Image image mode=RGB size=640x480 at 0x7F7D9FF898>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-36-b0bb56f609dd> in <module>
#      28     cv2.destroyAllWindows()
#      29
# ---> 30     sleep(2)
#
# KeyboardInterrupt:
